# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeybeast/Polynomial_regression/blob/main/polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset=pd.read_csv('Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=4)
poly2=poly.fit_transform(X)
linear2=LinearRegression()
linear2.fit(poly2,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,y,color='red')
plt.plot(X,linear.predict(X),color='blue')
plt.title('position vs salary')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,y,color='red')
plt.plot(X,linear2.predict(poly2),color='blue')
plt.title('position vs salary')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
x_room = np.arange(min(X), max(X), 0.1).reshape(-1, 1)  # Reshape x_room for prediction
plt.scatter(X, y, color='red')
plt.plot(x_room, linear2.predict(poly.fit_transform(x_room)), color='blue')
plt.title('Position vs Salary (Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# <ipython-input-27-c647746edd77>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_room = np.arange(min(X), max(X), 0.1).reshape(-1, 1)  # Reshape x_room for prediction

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
print(linear.predict([[6.5]]))
# Out:
# [330378.78787879]

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
print(linear2.predict(poly.transform([[6.5]])))
# Out:
# [158862.45265155]
